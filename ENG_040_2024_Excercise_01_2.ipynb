# %%
# Assign data to variables
principal = 172000
boe_rate = 2.25
extra_rate = 1.49

total_rate = boe_rate + extra_rate
rate_decimal = total_rate / 100

interest = principal * rate_decimal / 12

print(interest)
# Out:
# 536.0666666666667

# %%
import math

## test ##
assert math.isclose(interest, 536.0666666666667)
